# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import tifffile as tiff
import PyQt5

# %%
numbers = np.around(np.arange(0,1.1,0.1),1)
for n in numbers:
    im = tiff.imread(f'cgan_microstructure_24[{str(n)}].tif')
    plt.imshow(im)
    plt.show()

# %%
im = tiff.imread('cgan_microstructure_22[1].tif')
plt.imshow(im)
plt.show()
