# %%
import matplotlib.pyplot as plt
import numpy as np
import tifffile as tiff

# %%
im = tiff.imread('cgan_microstructure_1[0.5].tif')
plt.imshow(im)
plt.show()

# %%
im = tiff.imread('cgan_microstructure_1[0].tif')
plt.imshow(im)
plt.show()
