# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import numpy as np
import tifffile

# %%
figure(figsize=(10,10))
im = plt.imread('forest1.jpg')
plt.imshow(im)
#plt.xlim(700,828)
#plt.ylim(300,428)
plt.show()
print(im.shape)
# Out:
# (2679, 4800, 3)

# %%
figure(figsize=(10,10))
im = plt.imread('forest2.jpg')
plt.imshow(im)
#plt.xlim(700,828)
#plt.ylim(300,428)
plt.show()
print(im.shape)
# Out:
# (2679, 4800, 3)

# %%
figure(figsize=(10,10))
im = plt.imread('forest3.jpg')
plt.imshow(im)
#plt.xlim(700,828)
#plt.ylim(300,428)
plt.show()
print(im.shape)
# Out:
# (2679, 4800, 3)

# %%
im = np.moveaxis(im, -1, 0)
print(im.shape)
tifffile.imshow(im)
# Out:
# (3, 2679, 4800)
# (<Figure size 988.8x604.8 with 1 Axes>,
#  <AxesSubplot:>,
#  <matplotlib.image.AxesImage at 0x7f2cb4a783d0>)
