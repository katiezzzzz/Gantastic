# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import imagecodecs
import numpy as np
import tifffile
import os

# %%
figure(figsize=(10,10))
im = plt.imread('sea3.jpg')
plt.imshow(im)
#plt.xlim(700,800)
#plt.ylim(300,400)
plt.show()
print(im.shape)
# Out:
# (2679, 4800, 3)

# %%
im = np.moveaxis(im, -1, 0)
print(im.shape)
tifffile.imshow(im)
# Out:
# (3, 2679, 4800)
# (<Figure size 988.8x604.8 with 1 Axes>,
#  <AxesSubplot:>,
#  <matplotlib.image.AxesImage at 0x7f2cb4a783d0>)
