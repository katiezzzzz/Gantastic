# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff
from matplotlib.pyplot import figure

# %%
figure(figsize=(8, 6), dpi=80)
im = plt.imread('city1.jpg')
plt.xlim(300,428)
plt.ylim(0,128)
#plt.xlim(0,1000)
#plt.ylim(0,1000)
plt.imshow(im)
#plt.plot((300,300), (0,128), color='red')
#plt.plot((300,428), (128,128), color='red')
#plt.plot((428,428), (128,0), color='red')
#plt.plot((428,300), (0,0), color='red')
plt.show()
