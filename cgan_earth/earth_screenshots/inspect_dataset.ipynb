# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff
from matplotlib.pyplot import figure

# %%
figure(figsize=(8, 6), dpi=80)
im = plt.imread('city1.jpg')
plt.xlim(0,256)
plt.ylim(0,256)
plt.imshow(im)
plt.show()
